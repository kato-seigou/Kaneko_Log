# %%
dct = {}

key = "A"

dct[key] = 0

print(dct)
# Out:
# {'A': 0}

# %%
if "B" not in dct.keys():
    print("unko")
# Out:
# unko

# %%
key = "single"

grouped = {
    "Album": [("our hope", 50), ("Album2", 5)],
    "EP": [("EP1", 30), ("EP2", 25)],
    "Movie": [("Movie1", 10)]
}
if key not in grouped.keys():
    grouped[key] = []
print("1", grouped)

grouped[key].append(("test", 30))

print(grouped)
# Out:
# 1 {'Album': [('our hope', 50), ('Album2', 5)], 'EP': [('EP1', 30), ('EP2', 25)], 'Movie': [('Movie1', 10)], 'single': []}
# {'Album': [('our hope', 50), ('Album2', 5)], 'EP': [('EP1', 30), ('EP2', 25)], 'Movie': [('Movie1', 10)], 'single': [('test', 30)]}

# %%
grouped = {
    "Album": [("our hope", 50), ("Album2", 5)],
    "EP": [("EP1", 30), ("EP2", 25)],
    "Movie": [("Movie1", 10), ("Live2025", 1000)]
}

types = list(grouped.keys())

inner_labels = []
inner_data = []

for type in types:
    inner_labels.append(type)
    handle_list = grouped[type]
    sum_data = 0
    for data in handle_list:
        handle_data = data[1]
        sum_data += handle_data
    inner_data.append(sum_data)
    
print(inner_labels)
print(inner_data)
# Out:
# ['Album', 'EP', 'Movie']
# [55, 55, 1010]

# %%
outer_labels = []
outer_data = []

for type in grouped.keys():

# %%
# 全テスト
rows = [
    (1, "taoru", "EP", 100),
    (2, "hikareai", "EP", 10),
    (3, "kirameki", "Single", 100),
    (4, "alu", "Album", 10)
]

dtypes = ["Album", "EP", "Single", "Movie"]

# 1
grouped = {}
for row in rows:
    dtype = row[2]
    title = row[1]
    count = row[3]
    if dtype not in grouped.keys():
        grouped[dtype] = []  
    grouped[dtype].append((title, count))

# 2
inner_labels = []
inner_data = []
for dtype in dtypes:
    sum_data = 0
    for title, count in grouped.get(dtype, []):
        sum_data += count
    inner_labels.append(dtype)
    inner_data.append(sum_data)

# 3
outer_labels = []
outer_data = []
for i, dtype in enumerate(dtypes):
    title = row[1]
    count = row[2]
    if i == 0:
        outer_labels_inner = []
        outer_data_inner = []
    outer_labels_inner.append(count)
    
    
    
print(grouped)
print(inner_labels)
print(inner_data)
# Out:
# {'EP': [('taoru', 100), ('hikareai', 10)], 'Single': [('kirameki', 100)], 'Album': [('alu', 10)]}
# ['Album', 'EP', 'Single', 'Movie']
# [10, 110, 100, 0]
